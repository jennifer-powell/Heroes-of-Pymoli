# %%
import pandas as pd
import numpy as np

# %%
Pymoli = "Resources/purchase_data.csv"

# %%
Pymoli_df = pd.read_csv(Pymoli)
Pymoli_df.head(20)
# Out:
#     Purchase ID             SN  Age                 Gender  Item ID  \
# 0             0        Lisim78   20                   Male      108
# 1             1    Lisovynya38   40                   Male      143
# 2             2     Ithergue48   24                   Male       92
# 3             3  Chamassasya86   24                   Male      100
# 4             4      Iskosia90   23                   Male      131
# 5             5        Yalae81   22                   Male       81
# 6             6      Itheria73   36                   Male      169
# 7             7    Iskjaskst81   20                   Male      162
# 8             8      Undjask33   22                   Male       21
# 9             9    Chanosian48   35  Other / Non-Disclosed      136
# 10           10      Inguron55   23                   Male       95
# 11           11   Haisrisuir60   23                   Male      162
# 12           12   Saelaephos52   21                   Male      116
# 13           13    Assjaskan73   22                   Male        4
# 14           14    Saesrideu94   35                   Male      165
# 15           15      Lisassa64   21                 Female       98
# 16           16      Lisirra25   20                   Male       40
# 17           17      Zontibe81   21                   Male      161
# 18           18      Reunasu60   22                 Female       82
# 19           19      Chamalo71   30                   Male       89
#
#                                     Item Name  Price
# 0   Extraction, Quickblade Of Trembling Hands   3.53
# 1                           Frenzied Scimitar   1.56
# 2                                Final Critic   4.88
# 3                                 Blindscythe   3.27
# 4                                        Fury   1.44
# 5                                   Dreamkiss   3.61
# 6      Interrogator, Blood Blade of the Queen   2.18
# 7                               Abyssal Shard   2.67
# 8                                   Souleater   1.10
# 9                Ghastly Adamantite Protector   3.58
# 10                      Singed Onyx Warscythe   4.74
# 11                              Abyssal Shard   2.67
# 12                    Renewed Skeletal Katana   4.18
# 13                         Bloodlord's Fetish   1.70
# 14                Bone Crushing Silver Skewer   4.86
# 15                Deadline, Voice Of Subtlety   2.89
# 16                              Second Chance   2.52
# 17                                     Devine   1.76
# 18                                    Nirvana   4.90
# 19          Blazefury, Protector of Delusions   4.64

# %%
Total_Number_Purchase= Pymoli_df["Price"].count()
Total_Number_Purchase
# Out:
# 780

# %%
#Purchase Count
print (Pymoli_df["Age"].max())
print (Pymoli_df["Age"].min())
# Out:
# 45
# 7

# %%
#BINNING
bins= [0,10,14,19,24,29,34,39,45]
age_group_labels= ["<10","10-14","15-19", "20-24","25-29", "30-34", "35-39", "40+"]

# %%
#BINNING
pd.cut(Pymoli_df["Age"], bins, labels=age_group_labels).head()
# Out:
# 0    20-24
# 1      40+
# 2    20-24
# 3    20-24
# 4    20-24
# Name: Age, dtype: category
# Categories (8, object): [<10 < 10-14 < 15-19 < 20-24 < 25-29 < 30-34 < 35-39 < 40+]

# %%
#BINNING
Pymoli_df["View Age Group"] = pd.cut(Pymoli_df["Age"], bins, labels=age_group_labels)
Pymoli_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price View Age Group
# 0  Extraction, Quickblade Of Trembling Hands   3.53          20-24
# 1                          Frenzied Scimitar   1.56            40+
# 2                               Final Critic   4.88          20-24
# 3                                Blindscythe   3.27          20-24
# 4                                       Fury   1.44          20-24

# %%
#GROUPING BY AGE
age_group = Pymoli_df.groupby("View Age Group")

#finding total number of purchases in each age group
age_group_purch=age_group["Purchase ID"].count()
print(age_group_purch)

# Get the average of each column within the GroupBy object
#age_group[["comments", "duration", "languages"]].mean()
# Out:
# View Age Group
# <10       32
# 10-14     19
# 15-19    136
# 20-24    365
# 25-29    101
# 30-34     73
# 35-39     41
# 40+       13
# Name: Purchase ID, dtype: int64

# %%
#Percent of Purchases by Age Group
Percent_age_purch= (age_group_purch/Total_Number_Purchase)*100
Percent_age_purch
# Out:
# View Age Group
# <10       4.102564
# 10-14     2.435897
# 15-19    17.435897
# 20-24    46.794872
# 25-29    12.948718
# 30-34     9.358974
# 35-39     5.256410
# 40+       1.666667
# Name: Purchase ID, dtype: float64

# %%
#Average Purchase Price

ave_purch_price= age_group[["Price"]].mean()
ave_purch_price
# Out:
#                    Price
# View Age Group
# <10             3.405000
# 10-14           2.681579
# 15-19           3.035956
# 20-24           3.052219
# 25-29           2.900990
# 30-34           2.931507
# 35-39           3.601707
# 40+             2.941538

# %%
#Total Purchase Value
total_purchases=age_group[["Price"]].sum()
total_purchases
# Out:
#                   Price
# View Age Group
# <10              108.96
# 10-14             50.95
# 15-19            412.89
# 20-24           1114.06
# 25-29            293.00
# 30-34            214.00
# 35-39            147.67
# 40+               38.24

# %%
# Average Purchase Total per Person by Age Group
ave_per_player=age_group[["SN", "Price"]].mean()
ave_per_player
# Out:
#                    Price
# View Age Group
# <10             3.405000
# 10-14           2.681579
# 15-19           3.035956
# 20-24           3.052219
# 25-29           2.900990
# 30-34           2.931507
# 35-39           3.601707
# 40+             2.941538

# %%
age_group_df=[{Percent_age_purch, ave_purch_price,total_purchases,ave_per_player}]
# Out:
# ------------------------------------------------
# TypeError      Traceback (most recent call last)
# <ipython-input-36-57411d819ae4> in <module>
# ----> 1 age_group_df=[{Percent_age_purch, ave_purch_price,total_purchases,ave_per_player}]
#
# ~\anaconda4\envs\PythonData\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1797     def __hash__(self):
#    1798         raise TypeError(
# -> 1799             f"{repr(type(self).__name__)} objects are mutable, "
#    1800             f"thus they cannot be hashed"
#    1801         )
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
